# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras

from tqdm import tqdm
from nltk import sent_tokenize
import tensorflow_datasets as tfds
from rouge import Rouge
from transformers import TFBertModel, BertTokenizer, BertConfig, BertModel
import torch
rouge = Rouge()
import nltk

import os
os.environ["CUDA_VISIBLE_DEVICES"]='0'

configuration = BertConfig()
bertmodel = TFBertModel(configuration)
tokenizer = BertTokenizer.from_pretrained('../dataset/BertModel/uncased_L-12_H-768_A-12', do_lower_case=True)
sent_maxlen=80
import torch
dataset = [torch.load(f'data/CNN_bert_data/cnndm.train.{i}.bert.pt') for i in range(50)]
dataset = sum(dataset, [])
doc_maxlen = max([len(i['clss']) for i in dataset])
from sklearn.model_selection import train_test_split
data_train, data_eval= train_test_split(dataset, test_size = 0.1)

# %%
start_adj = time.time()
src_text_train = [i['src_txt'] for i in dataset]
from lexrank import LexRank
from lexrank.mappings.stopwords import STOPWORDS
from path import Path
lxr = LexRank(src_text_train, stopwords=STOPWORDS['en'])
complete_time = time.time() - start_adj

# %%
import dill
f=open('cnn_lxr.pkl','rb') 
lxr = dill.load(f)

# %%
batch_size = 5
nbatch = len(data_train)//batch_size
train_batches = [data_train[i:i+batch_size] for i in range(nbatch)]

from collections import Counter
def make_adj(batch_data):
    adj_matrixs = []
    for i in range(len(batch_data)):
        src_txt = [e['src_txt'] for e in batch_data]
        tf_scores = [Counter(lxr.tokenize_sentence(sentence)) for sentence in src_txt[i]]
        adj = lxr._calculate_similarity_matrix(tf_scores)
        n = adj.shape[0]
        if doc_maxlen>=n:
            adj = tf.pad(adj, [[0, doc_maxlen - n], [0, doc_maxlen - n]])
        else:
            
        adj = tf.expand_dims(adj, 0)
        adj_matrixs.append(adj)
        adj_matrix = tf.concat(adj_matrixs, axis=0)
        adj_matrix = tf.cast(adj_matrix, tf.float32)
    return adj_matrix

def _pad(data, pad_id, width=-1):
    if (width == -1):
        width = max(len(d) for d in data)
    rtn_data = [d + [pad_id] * (width - len(d)) for d in data]
    return rtn_data
def make_batch(data):
    pre_src = [x['src'] for x in data]
    pre_labels = [x['labels'] for x in data]
    pre_segs = [x['segs'] for x in data]
    pre_clss = [x['clss'] for x in data]
    adj = make_adj(data)
    
    src = tf.convert_to_tensor(_pad(pre_src, 0))
    labels = tf.convert_to_tensor(_pad(pre_labels, 0, doc_maxlen))
    segs = tf.convert_to_tensor(_pad(pre_segs, 0))
    mask = ~(src == 0)
    clss = np.array(_pad(pre_clss, -1, doc_maxlen))
    mask_cls = ~(clss == -1)
    clss[clss == -1] = 0
    
    return src, segs, clss, mask, mask_cls, adj, labels

class Bert(keras.layers.Layer):
    def __init__(self):
        super(Bert, self).__init__()
        self.model = TFBertModel(configuration)

    def call(self, x, segs, mask):
        output = self.model(x, attention_mask=mask, token_type_ids=segs, output_attentions=True)
        return output

class GCN(layers.Layer):
    def __init__(self, output_dim):
        super(GCN, self).__init__()
        self.fc = layers.Dense(output_dim)
    def call(self, x, adj):
        x = self.fc(x)
        out = tf.matmul(adj, x)
        out = tf.nn.relu(out)
        return out
    
class Classifier(keras.Model):
    def __init__(self):
        super(Classifier, self).__init__()
        self.bert = Bert()
        self.fc1 = layers.Dense(512, kernel_initializer=tf.initializers.RandomUniform(), activation='sigmoid')
        self.fc2 = layers.Dense(512, kernel_initializer=tf.initializers.RandomUniform())
        self.fc3 = layers.Dense(1, kernel_initializer=tf.initializers.RandomUniform(), activation='sigmoid')
        self.gcn1 = GCN(600)
        self.gcn2 = GCN(300)
        # self.flatten = layers.Flatten()

    def call(self, x, segs, clss, mask, mask_cls, adj):
        output = self.bert(x, segs, mask)
        top_vecs = output[0]
        sents_vec = tf.stack([tf.gather(top_vec, cls, axis=0) for top_vec, cls in zip(top_vecs, clss)])
        sents_vec = sents_vec*mask_cls[..., tf.newaxis]
    
        out1 = self.gcn1(sents_vec, adj)
        # x *= mask[...,np.newaxis]
        out2 = self.gcn2(out1, adj)
        # x *= mask[...,np.newaxis]
        val1 = self.fc1(tf.concat([out2, sents_vec], axis=2))
        val2 = self.fc2(out2)
        out3 = tf.multiply(val1, val2)
        # out3 = tf.reduce_mean(out3, axis=1)
        out3 = tf.nn.relu(out3)
        # x = self.flatten(x)
        out = tf.squeeze(self.fc3(out3))
        return out*mask_cls
    
classifier = Classifier()
classifier.bert.trainable = False

# %%
optimizer = keras.optimizers.Adam()
loss_fcn = keras.losses.BinaryCrossentropy()

def train_step(src, segs, clss, mask, mask_cls, adj, labels):
    loss = 0
    with tf.GradientTape() as tape:
        logit = classifier(src, segs, clss, mask, mask_cls, adj)
        loss += loss_fcn(labels, logit)
  
    variable = classifier.trainable_variables
    gradients = tape.gradient(loss, variable)
    optimizer.apply_gradients(zip(gradients, variable))
    return tf.reduce_sum(loss)

nbatch_eval = len(data_eval)//batch_size
eval_batches = [data_eval[i:i+batch_size] for i in range(nbatch_eval)]

# %%
para = 0
for w in classifier.trainable_weights:
    if len(w.shape)==2:
        para += w.shape[0]*w.shape[1]
    else:
        para += w.shape[0]
print(para)
# Out:
# 1343653

# %%
tf.random.set_seed=1968
epochs = 1
history_train = []
history_valid = []
for epoch in range(epochs):
    start = time.time()
    total_loss = 0
    for i, batch in enumerate(train_batches):
        src, segs, clss, mask, mask_cls, adj, labels = make_batch(batch)
        batch_loss = train_step(src, segs, clss, mask, mask_cls, adj, labels)
        total_loss += batch_loss
        if i % 5 == 0 and i > 0:
            cur_loss = total_loss / 5
            elapsed = time.time() - start
            src_, segs_, clss_, mask_, mask_cls_, adj_, labels_ = make_batch(eval_batches[3])
            out_valid = classifier(src_, segs_, clss_, mask_, mask_cls_, adj_)
            loss_valid = loss_fcn(labels_, out_valid)
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'ms/batch {:5.2f} | '
                  'loss {:5.2f} | valid {:5.2f}'.format(
                    epoch, i, nbatch,
                    elapsed,
                    cur_loss.numpy(), loss_valid))
            total_loss = 0
            start_time = time.time()

    # s = epoch%len(input_eval)//batch
    out_valid = classifier(src_, segs_, clss_, mask_, mask_cls_, adj_)
    loss_valid = loss_fcn(labels_, out_valid)

    history_train.append(total_loss/nbatch)
    history_valid.append(loss_valid)
    
    print('\n')
    print(f'Epoch{epoch} Loss:{total_loss/nbatch}')
    print(f'Loss Validation:{loss_valid}')
    print(f'Time {time.time()-start}')
# Out:
# | epoch   0 |     5/18000 batches | ms/batch  3.35 | loss  0.62 | valid  0.18
# | epoch   0 |    10/18000 batches | ms/batch  5.78 | loss  0.17 | valid  0.15
# | epoch   0 |    15/18000 batches | ms/batch  8.28 | loss  0.12 | valid  0.15
# | epoch   0 |    20/18000 batches | ms/batch 10.66 | loss  0.13 | valid  0.14
# | epoch   0 |    25/18000 batches | ms/batch 14.79 | loss  0.16 | valid  0.13
# | epoch   0 |    30/18000 batches | ms/batch 17.27 | loss  0.14 | valid  0.13
# | epoch   0 |    35/18000 batches | ms/batch 19.75 | loss  0.12 | valid  0.13
# | epoch   0 |    40/18000 batches | ms/batch 22.09 | loss  0.13 | valid  0.13
# | epoch   0 |    45/18000 batches | ms/batch 24.80 | loss  0.14 | valid  0.14
# | epoch   0 |    50/18000 batches | ms/batch 27.75 | loss  0.15 | valid  0.24
# | epoch   0 |    55/18000 batches | ms/batch 30.25 | loss  0.16 | valid  0.13
# | epoch   0 |    60/18000 batches | ms/batch 32.62 | loss  0.15 | valid  0.13
# | epoch   0 |    65/18000 batches | ms/batch 35.33 | loss  0.19 | valid  0.18
# | epoch   0 |    70/18000 batches | ms/batch 37.79 | loss  0.20 | valid  0.15
# | epoch   0 |    75/18000 batches | ms/batch 40.07 | loss  0.14 | valid  0.12
# | epoch   0 |    80/18000 batches | ms/batch 42.62 | loss  0.13 | valid  0.12
# | epoch   0 |    85/18000 batches | ms/batch 45.00 | loss  0.13 | valid  0.13
# | epoch   0 |    90/18000 batches | ms/batch 47.85 | loss  0.16 | valid  0.13
# | epoch   0 |    95/18000 batches | ms/batch 50.48 | loss  0.12 | valid  0.12
# | epoch   0 |   100/18000 batches | ms/batch 52.78 | loss  0.13 | valid  0.12
# | epoch   0 |   105/18000 batches | ms/batch 55.26 | loss  0.11 | valid  0.11
# | epoch   0 |   110/18000 batches | ms/batch 57.71 | loss  0.15 | valid  0.13
# | epoch   0 |   115/18000 batches | ms/batch 60.30 | loss  0.15 | valid  0.13
# | epoch   0 |   120/18000 batches | ms/batch 63.00 | loss  0.13 | valid  0.14
# | epoch   0 |   125/18000 batches | ms/batch 65.92 | loss  0.17 | valid  0.14
# | epoch   0 |   130/18000 batches | ms/batch 68.41 | loss  0.15 | valid  0.13
# | epoch   0 |   135/18000 batches | ms/batch 70.91 | loss  0.12 | valid  0.13
# | epoch   0 |   140/18000 batches | ms/batch 73.36 | loss  0.12 | valid  0.12
# | epoch   0 |   145/18000 batches | ms/batch 75.72 | loss  0.13 | valid  0.17
# | epoch   0 |   150/18000 batches | ms/batch 78.23 | loss  0.17 | valid  0.17
# | epoch   0 |   155/18000 batches | ms/batch 80.75 | loss  0.18 | valid  0.26
# | epoch   0 |   160/18000 batches | ms/batch 83.13 | loss  0.29 | valid  0.30
# | epoch   0 |   165/18000 batches | ms/batch 85.64 | loss  0.15 | valid  0.16
# | epoch   0 |   170/18000 batches | ms/batch 88.30 | loss  0.15 | valid  0.13
# | epoch   0 |   175/18000 batches | ms/batch 90.79 | loss  0.17 | valid  0.13
# | epoch   0 |   180/18000 batches | ms/batch 93.24 | loss  0.15 | valid  0.15
# | epoch   0 |   185/18000 batches | ms/batch 95.71 | loss  0.15 | valid  0.13
# | epoch   0 |   190/18000 batches | ms/batch 97.96 | loss  0.13 | valid  0.12
# | epoch   0 |   195/18000 batches | ms/batch 100.33 | loss  0.14 | valid  0.14
# | epoch   0 |   200/18000 batches | ms/batch 102.84 | loss  0.13 | valid  0.12
# | epoch   0 |   205/18000 batches | ms/batch 105.30 | loss  0.13 | valid  0.13
# | epoch   0 |   210/18000 batches | ms/batch 107.68 | loss  0.13 | valid  0.13
# | epoch   0 |   215/18000 batches | ms/batch 110.25 | loss  0.15 | valid  0.13
# | epoch   0 |   220/18000 batches | ms/batch 113.01 | loss  0.13 | valid  0.12
# | epoch   0 |   225/18000 batches | ms/batch 115.81 | loss  0.13 | valid  0.12
# | epoch   0 |   230/18000 batches | ms/batch 118.32 | loss  0.13 | valid  0.12
# | epoch   0 |   235/18000 batches | ms/batch 120.86 | loss  0.13 | valid  0.11
# | epoch   0 |   240/18000 batches | ms/batch 123.46 | loss  0.15 | valid  0.12
# | epoch   0 |   245/18000 batches | ms/batch 126.03 | loss  0.14 | valid  0.12
# | epoch   0 |   250/18000 batches | ms/batch 128.87 | loss  0.12 | valid  0.12
# | epoch   0 |   255/18000 batches | ms/batch 131.50 | loss  0.12 | valid  0.11
# | epoch   0 |   260/18000 batches | ms/batch 133.93 | loss  0.14 | valid  0.12
# | epoch   0 |   265/18000 batches | ms/batch 136.37 | loss  0.15 | valid  0.15
# | epoch   0 |   270/18000 batches | ms/batch 138.85 | loss  0.15 | valid  0.11
# | epoch   0 |   275/18000 batches | ms/batch 141.30 | loss  0.14 | valid  0.13
# | epoch   0 |   280/18000 batches | ms/batch 143.95 | loss  0.15 | valid  0.12
# | epoch   0 |   285/18000 batches | ms/batch 146.65 | loss  0.14 | valid  0.13
# | epoch   0 |   290/18000 batches | ms/batch 149.20 | loss  0.14 | valid  0.13
# | epoch   0 |   295/18000 batches | ms/batch 151.62 | loss  0.14 | valid  0.12
# | epoch   0 |   300/18000 batches | ms/batch 154.22 | loss  0.14 | valid  0.12
# | epoch   0 |   305/18000 batches | ms/batch 157.06 | loss  0.13 | valid  0.12
# | epoch   0 |   310/18000 batches | ms/batch 159.64 | loss  0.14 | valid  0.13
# | epoch   0 |   315/18000 batches | ms/batch 162.08 | loss  0.14 | valid  0.16
# | epoch   0 |   320/18000 batches | ms/batch 164.72 | loss  0.13 | valid  0.14
# | epoch   0 |   325/18000 batches | ms/batch 167.23 | loss  0.15 | valid  0.12
# | epoch   0 |   330/18000 batches | ms/batch 169.76 | loss  0.13 | valid  0.13
# | epoch   0 |   335/18000 batches | ms/batch 172.23 | loss  0.12 | valid  0.13
# | epoch   0 |   340/18000 batches | ms/batch 175.01 | loss  0.12 | valid  0.12
# | epoch   0 |   345/18000 batches | ms/batch 177.49 | loss  0.14 | valid  0.12
# | epoch   0 |   350/18000 batches | ms/batch 179.98 | loss  0.14 | valid  0.13
# | epoch   0 |   355/18000 batches | ms/batch 182.49 | loss  0.15 | valid  0.15
# | epoch   0 |   360/18000 batches | ms/batch 184.90 | loss  0.15 | valid  0.13
# | epoch   0 |   365/18000 batches | ms/batch 187.82 | loss  0.15 | valid  0.12
# | epoch   0 |   370/18000 batches | ms/batch 190.19 | loss  0.15 | valid  0.11
# | epoch   0 |   375/18000 batches | ms/batch 192.77 | loss  0.12 | valid  0.11
# | epoch   0 |   380/18000 batches | ms/batch 195.14 | loss  0.14 | valid  0.11
# | epoch   0 |   385/18000 batches | ms/batch 197.40 | loss  0.16 | valid  0.16
# | epoch   0 |   390/18000 batches | ms/batch 200.07 | loss  0.17 | valid  0.13
# | epoch   0 |   395/18000 batches | ms/batch 202.78 | loss  0.12 | valid  0.12
# | epoch   0 |   400/18000 batches | ms/batch 205.39 | loss  0.14 | valid  0.12
# | epoch   0 |   405/18000 batches | ms/batch 208.46 | loss  0.15 | valid  0.12
# | epoch   0 |   410/18000 batches | ms/batch 211.57 | loss  0.15 | valid  0.12
# | epoch   0 |   415/18000 batches | ms/batch 214.51 | loss  0.14 | valid  0.11
# | epoch   0 |   420/18000 batches | ms/batch 217.13 | loss  0.14 | valid  0.12
# | epoch   0 |   425/18000 batches | ms/batch 219.81 | loss  0.13 | valid  0.12
# | epoch   0 |   430/18000 batches | ms/batch 222.36 | loss  0.14 | valid  0.14
# | epoch   0 |   435/18000 batches | ms/batch 224.77 | loss  0.16 | valid  0.12
# | epoch   0 |   440/18000 batches | ms/batch 227.16 | loss  0.15 | valid  0.11
# | epoch   0 |   445/18000 batches | ms/batch 229.74 | loss  0.12 | valid  0.12
# | epoch   0 |   450/18000 batches | ms/batch 232.21 | loss  0.18 | valid  0.15
# | epoch   0 |   455/18000 batches | ms/batch 234.64 | loss  0.16 | valid  0.16
# | epoch   0 |   460/18000 batches | ms/batch 237.48 | loss  0.16 | valid  0.14
# | epoch   0 |   465/18000 batches | ms/batch 240.00 | loss  0.13 | valid  0.15
# | epoch   0 |   470/18000 batches | ms/batch 244.07 | loss  0.15 | valid  0.13
# | epoch   0 |   475/18000 batches | ms/batch 246.36 | loss  0.16 | valid  0.13
# | epoch   0 |   480/18000 batches | ms/batch 248.99 | loss  0.14 | valid  0.13
# | epoch   0 |   485/18000 batches | ms/batch 251.67 | loss  0.14 | valid  0.14
# | epoch   0 |   490/18000 batches | ms/batch 254.23 | loss  0.13 | valid  0.13
# | epoch   0 |   495/18000 batches | ms/batch 257.18 | loss  0.12 | valid  0.14
# | epoch   0 |   500/18000 batches | ms/batch 259.96 | loss  0.12 | valid  0.15
# | epoch   0 |   505/18000 batches | ms/batch 262.39 | loss  0.13 | valid  0.15
# | epoch   0 |   510/18000 batches | ms/batch 264.83 | loss  0.18 | valid  0.14
# | epoch   0 |   515/18000 batches | ms/batch 267.20 | loss  0.14 | valid  0.13
# | epoch   0 |   520/18000 batches | ms/batch 269.73 | loss  0.13 | valid  0.12
# | epoch   0 |   525/18000 batches | ms/batch 272.33 | loss  0.14 | valid  0.12
# | epoch   0 |   530/18000 batches | ms/batch 274.80 | loss  0.15 | valid  0.13
# | epoch   0 |   535/18000 batches | ms/batch 277.73 | loss  0.15 | valid  0.12
# | epoch   0 |   540/18000 batches | ms/batch 280.11 | loss  0.14 | valid  0.11
# | epoch   0 |   545/18000 batches | ms/batch 282.47 | loss  0.12 | valid  0.16
# | epoch   0 |   550/18000 batches | ms/batch 285.32 | loss  0.11 | valid  0.12
# | epoch   0 |   555/18000 batches | ms/batch 287.80 | loss  0.12 | valid  0.12
# | epoch   0 |   560/18000 batches | ms/batch 290.66 | loss  0.13 | valid  0.11
# | epoch   0 |   565/18000 batches | ms/batch 293.31 | loss  0.10 | valid  0.11
# | epoch   0 |   570/18000 batches | ms/batch 295.95 | loss  0.12 | valid  0.12
# | epoch   0 |   575/18000 batches | ms/batch 298.76 | loss  0.12 | valid  0.12
# | epoch   0 |   580/18000 batches | ms/batch 301.34 | loss  0.13 | valid  0.11
# | epoch   0 |   585/18000 batches | ms/batch 303.85 | loss  0.12 | valid  0.12
# | epoch   0 |   590/18000 batches | ms/batch 306.29 | loss  0.12 | valid  0.11
# | epoch   0 |   595/18000 batches | ms/batch 308.88 | loss  0.11 | valid  0.12
# | epoch   0 |   600/18000 batches | ms/batch 311.47 | loss  0.14 | valid  0.13
# | epoch   0 |   605/18000 batches | ms/batch 313.91 | loss  0.13 | valid  0.13
# | epoch   0 |   610/18000 batches | ms/batch 316.66 | loss  0.13 | valid  0.12
# | epoch   0 |   615/18000 batches | ms/batch 319.45 | loss  0.13 | valid  0.13
# | epoch   0 |   620/18000 batches | ms/batch 322.15 | loss  0.12 | valid  0.13
# | epoch   0 |   625/18000 batches | ms/batch 324.84 | loss  0.13 | valid  0.13
# | epoch   0 |   630/18000 batches | ms/batch 327.59 | loss  0.14 | valid  0.12
# | epoch   0 |   635/18000 batches | ms/batch 330.00 | loss  0.15 | valid  0.12
# | epoch   0 |   640/18000 batches | ms/batch 332.31 | loss  0.13 | valid  0.12
# | epoch   0 |   645/18000 batches | ms/batch 334.66 | loss  0.13 | valid  0.12
# | epoch   0 |   650/18000 batches | ms/batch 337.13 | loss  0.14 | valid  0.14
# | epoch   0 |   655/18000 batches | ms/batch 339.64 | loss  0.15 | valid  0.14
# | epoch   0 |   660/18000 batches | ms/batch 342.12 | loss  0.14 | valid  0.13
# | epoch   0 |   665/18000 batches | ms/batch 344.49 | loss  0.15 | valid  0.11
# | epoch   0 |   670/18000 batches | ms/batch 346.84 | loss  0.13 | valid  0.12
# | epoch   0 |   675/18000 batches | ms/batch 349.49 | loss  0.10 | valid  0.15
# | epoch   0 |   680/18000 batches | ms/batch 352.12 | loss  0.13 | valid  0.12
# | epoch   0 |   685/18000 batches | ms/batch 354.94 | loss  0.12 | valid  0.12
# | epoch   0 |   690/18000 batches | ms/batch 357.99 | loss  0.08 | valid  0.14
# | epoch   0 |   695/18000 batches | ms/batch 360.91 | loss  0.11 | valid  0.17
# | epoch   0 |   700/18000 batches | ms/batch 363.62 | loss  0.15 | valid  0.13
# | epoch   0 |   705/18000 batches | ms/batch 366.45 | loss  0.12 | valid  0.13
# | epoch   0 |   710/18000 batches | ms/batch 369.30 | loss  0.15 | valid  0.14
# | epoch   0 |   715/18000 batches | ms/batch 371.64 | loss  0.16 | valid  0.13
# | epoch   0 |   720/18000 batches | ms/batch 374.05 | loss  0.15 | valid  0.12
# | epoch   0 |   725/18000 batches | ms/batch 376.53 | loss  0.14 | valid  0.12
# | epoch   0 |   730/18000 batches | ms/batch 379.08 | loss  0.14 | valid  0.12
# | epoch   0 |   735/18000 batches | ms/batch 381.48 | loss  0.11 | valid  0.12
# | epoch   0 |   740/18000 batches | ms/batch 384.20 | loss  0.12 | valid  0.13
# | epoch   0 |   745/18000 batches | ms/batch 387.00 | loss  0.11 | valid  0.12
# | epoch   0 |   750/18000 batches | ms/batch 389.70 | loss  0.12 | valid  0.15
# | epoch   0 |   755/18000 batches | ms/batch 392.25 | loss  0.15 | valid  0.12
# | epoch   0 |   760/18000 batches | ms/batch 394.77 | loss  0.12 | valid  0.12
# | epoch   0 |   765/18000 batches | ms/batch 397.27 | loss  0.13 | valid  0.13
# | epoch   0 |   770/18000 batches | ms/batch 399.87 | loss  0.12 | valid  0.12
# | epoch   0 |   775/18000 batches | ms/batch 402.50 | loss  0.13 | valid  0.12
# | epoch   0 |   780/18000 batches | ms/batch 405.00 | loss  0.13 | valid  0.13
# | epoch   0 |   785/18000 batches | ms/batch 407.64 | loss  0.11 | valid  0.19
# | epoch   0 |   790/18000 batches | ms/batch 411.59 | loss  0.11 | valid  0.16
# | epoch   0 |   795/18000 batches | ms/batch 414.15 | loss  0.12 | valid  0.21
# | epoch   0 |   800/18000 batches | ms/batch 416.55 | loss  0.17 | valid  0.13
# | epoch   0 |   805/18000 batches | ms/batch 418.99 | loss  0.15 | valid  0.15
# | epoch   0 |   810/18000 batches | ms/batch 421.50 | loss  0.15 | valid  0.12
# | epoch   0 |   815/18000 batches | ms/batch 424.12 | loss  0.14 | valid  0.13
# | epoch   0 |   820/18000 batches | ms/batch 426.55 | loss  0.16 | valid  0.13
# | epoch   0 |   825/18000 batches | ms/batch 429.30 | loss  0.13 | valid  0.12
# | epoch   0 |   830/18000 batches | ms/batch 431.93 | loss  0.12 | valid  0.12
# | epoch   0 |   835/18000 batches | ms/batch 434.66 | loss  0.14 | valid  0.12
# | epoch   0 |   840/18000 batches | ms/batch 437.19 | loss  0.15 | valid  0.12
# | epoch   0 |   845/18000 batches | ms/batch 439.86 | loss  0.13 | valid  0.14
# | epoch   0 |   850/18000 batches | ms/batch 442.67 | loss  0.13 | valid  0.13
# | epoch   0 |   855/18000 batches | ms/batch 445.05 | loss  0.12 | valid  0.14
# | epoch   0 |   860/18000 batches | ms/batch 447.39 | loss  0.15 | valid  0.15
# | epoch   0 |   865/18000 batches | ms/batch 449.64 | loss  0.14 | valid  0.13
# | epoch   0 |   870/18000 batches | ms/batch 452.04 | loss  0.15 | valid  0.13
# | epoch   0 |   875/18000 batches | ms/batch 454.44 | loss  0.14 | valid  0.15
# | epoch   0 |   880/18000 batches | ms/batch 457.07 | loss  0.12 | valid  0.14
# | epoch   0 |   885/18000 batches | ms/batch 459.66 | loss  0.13 | valid  0.13
# | epoch   0 |   890/18000 batches | ms/batch 462.10 | loss  0.15 | valid  0.12
# | epoch   0 |   895/18000 batches | ms/batch 464.77 | loss  0.15 | valid  0.13
# | epoch   0 |   900/18000 batches | ms/batch 467.39 | loss  0.13 | valid  0.13
# | epoch   0 |   905/18000 batches | ms/batch 470.01 | loss  0.11 | valid  0.12
# | epoch   0 |   910/18000 batches | ms/batch 472.79 | loss  0.14 | valid  0.12
# | epoch   0 |   915/18000 batches | ms/batch 475.21 | loss  0.16 | valid  0.13
# | epoch   0 |   920/18000 batches | ms/batch 477.44 | loss  0.14 | valid  0.15
# | epoch   0 |   925/18000 batches | ms/batch 479.93 | loss  0.14 | valid  0.13
# | epoch   0 |   930/18000 batches | ms/batch 482.25 | loss  0.15 | valid  0.12
# | epoch   0 |   935/18000 batches | ms/batch 484.90 | loss  0.14 | valid  0.12
# | epoch   0 |   940/18000 batches | ms/batch 487.67 | loss  0.15 | valid  0.13
# | epoch   0 |   945/18000 batches | ms/batch 490.24 | loss  0.13 | valid  0.12
# | epoch   0 |   950/18000 batches | ms/batch 492.61 | loss  0.15 | valid  0.12
# | epoch   0 |   955/18000 batches | ms/batch 495.08 | loss  0.16 | valid  0.12
# | epoch   0 |   960/18000 batches | ms/batch 497.83 | loss  0.17 | valid  0.12
# | epoch   0 |   965/18000 batches | ms/batch 500.45 | loss  0.14 | valid  0.13
# | epoch   0 |   970/18000 batches | ms/batch 502.97 | loss  0.15 | valid  0.13
# | epoch   0 |   975/18000 batches | ms/batch 505.48 | loss  0.14 | valid  0.12
# | epoch   0 |   980/18000 batches | ms/batch 508.06 | loss  0.15 | valid  0.12
# | epoch   0 |   985/18000 batches | ms/batch 510.58 | loss  0.13 | valid  0.13
# | epoch   0 |   990/18000 batches | ms/batch 513.25 | loss  0.12 | valid  0.12
# | epoch   0 |   995/18000 batches | ms/batch 516.00 | loss  0.14 | valid  0.12
# | epoch   0 |  1000/18000 batches | ms/batch 518.79 | loss  0.14 | valid  0.13
# | epoch   0 |  1005/18000 batches | ms/batch 521.46 | loss  0.10 | valid  0.18
# | epoch   0 |  1010/18000 batches | ms/batch 524.16 | loss  0.14 | valid  0.12
# | epoch   0 |  1015/18000 batches | ms/batch 526.52 | loss  0.12 | valid  0.12
# | epoch   0 |  1020/18000 batches | ms/batch 528.92 | loss  0.13 | valid  0.12
# | epoch   0 |  1025/18000 batches | ms/batch 531.34 | loss  0.12 | valid  0.12
# | epoch   0 |  1030/18000 batches | ms/batch 533.86 | loss  0.16 | valid  0.12
# | epoch   0 |  1035/18000 batches | ms/batch 536.49 | loss  0.16 | valid  0.13
# | epoch   0 |  1040/18000 batches | ms/batch 539.22 | loss  0.13 | valid  0.13
# | epoch   0 |  1045/18000 batches | ms/batch 541.48 | loss  0.15 | valid  0.12
# | epoch   0 |  1050/18000 batches | ms/batch 543.76 | loss  0.14 | valid  0.12
# | epoch   0 |  1055/18000 batches | ms/batch 546.35 | loss  0.15 | valid  0.12
# | epoch   0 |  1060/18000 batches | ms/batch 548.80 | loss  0.12 | valid  0.14
# | epoch   0 |  1065/18000 batches | ms/batch 551.19 | loss  0.16 | valid  0.13
# | epoch   0 |  1070/18000 batches | ms/batch 553.62 | loss  0.15 | valid  0.14
# | epoch   0 |  1075/18000 batches | ms/batch 556.07 | loss  0.13 | valid  0.14
# | epoch   0 |  1080/18000 batches | ms/batch 558.61 | loss  0.15 | valid  0.16
# | epoch   0 |  1085/18000 batches | ms/batch 561.04 | loss  0.16 | valid  0.13
# | epoch   0 |  1090/18000 batches | ms/batch 563.41 | loss  0.13 | valid  0.15
# | epoch   0 |  1095/18000 batches | ms/batch 566.11 | loss  0.14 | valid  0.13
# | epoch   0 |  1100/18000 batches | ms/batch 568.72 | loss  0.14 | valid  0.13
# | epoch   0 |  1105/18000 batches | ms/batch 571.13 | loss  0.12 | valid  0.12
# | epoch   0 |  1110/18000 batches | ms/batch 573.55 | loss  0.13 | valid  0.12
# | epoch   0 |  1115/18000 batches | ms/batch 576.06 | loss  0.14 | valid  0.12
# | epoch   0 |  1120/18000 batches | ms/batch 578.70 | loss  0.17 | valid  0.13
# | epoch   0 |  1125/18000 batches | ms/batch 581.25 | loss  0.15 | valid  0.13
# | epoch   0 |  1130/18000 batches | ms/batch 583.59 | loss  0.13 | valid  0.13
# | epoch   0 |  1135/18000 batches | ms/batch 586.31 | loss  0.14 | valid  0.12
# | epoch   0 |  1140/18000 batches | ms/batch 588.79 | loss  0.12 | valid  0.12
# | epoch   0 |  1145/18000 batches | ms/batch 591.18 | loss  0.14 | valid  0.12
# | epoch   0 |  1150/18000 batches | ms/batch 593.64 | loss  0.12 | valid  0.15
# | epoch   0 |  1155/18000 batches | ms/batch 596.03 | loss  0.14 | valid  0.12
# | epoch   0 |  1160/18000 batches | ms/batch 598.40 | loss  0.13 | valid  0.13
# | epoch   0 |  1165/18000 batches | ms/batch 600.94 | loss  0.14 | valid  0.12
# | epoch   0 |  1170/18000 batches | ms/batch 603.26 | loss  0.14 | valid  0.12
# | epoch   0 |  1175/18000 batches | ms/batch 605.59 | loss  0.14 | valid  0.12
# | epoch   0 |  1180/18000 batches | ms/batch 608.43 | loss  0.12 | valid  0.12
# | epoch   0 |  1185/18000 batches | ms/batch 611.03 | loss  0.12 | valid  0.13
# | epoch   0 |  1190/18000 batches | ms/batch 613.38 | loss  0.16 | valid  0.13
# | epoch   0 |  1195/18000 batches | ms/batch 616.07 | loss  0.15 | valid  0.13
# | epoch   0 |  1200/18000 batches | ms/batch 618.63 | loss  0.16 | valid  0.13
# | epoch   0 |  1205/18000 batches | ms/batch 621.34 | loss  0.14 | valid  0.12
# | epoch   0 |  1210/18000 batches | ms/batch 623.83 | loss  0.14 | valid  0.12
# | epoch   0 |  1215/18000 batches | ms/batch 626.31 | loss  0.12 | valid  0.12
# | epoch   0 |  1220/18000 batches | ms/batch 628.81 | loss  0.15 | valid  0.12
# | epoch   0 |  1225/18000 batches | ms/batch 631.29 | loss  0.18 | valid  0.12
# | epoch   0 |  1230/18000 batches | ms/batch 634.25 | loss  0.13 | valid  0.13
# | epoch   0 |  1235/18000 batches | ms/batch 636.99 | loss  0.13 | valid  0.12
# | epoch   0 |  1240/18000 batches | ms/batch 641.49 | loss  0.10 | valid  0.12
# | epoch   0 |  1245/18000 batches | ms/batch 644.17 | loss  0.12 | valid  0.12
# | epoch   0 |  1250/18000 batches | ms/batch 646.62 | loss  0.14 | valid  0.11
# | epoch   0 |  1255/18000 batches | ms/batch 649.04 | loss  0.12 | valid  0.12
# | epoch   0 |  1260/18000 batches | ms/batch 651.56 | loss  0.13 | valid  0.13
# | epoch   0 |  1265/18000 batches | ms/batch 654.40 | loss  0.15 | valid  0.12
# | epoch   0 |  1270/18000 batches | ms/batch 657.02 | loss  0.14 | valid  0.12
# | epoch   0 |  1275/18000 batches | ms/batch 659.57 | loss  0.15 | valid  0.13
# | epoch   0 |  1280/18000 batches | ms/batch 662.22 | loss  0.14 | valid  0.13
# | epoch   0 |  1285/18000 batches | ms/batch 664.95 | loss  0.13 | valid  0.12
# | epoch   0 |  1290/18000 batches | ms/batch 667.52 | loss  0.13 | valid  0.11
# | epoch   0 |  1295/18000 batches | ms/batch 670.01 | loss  0.15 | valid  0.12
# | epoch   0 |  1300/18000 batches | ms/batch 672.51 | loss  0.15 | valid  0.12
# | epoch   0 |  1305/18000 batches | ms/batch 675.06 | loss  0.12 | valid  0.13
# | epoch   0 |  1310/18000 batches | ms/batch 677.60 | loss  0.14 | valid  0.13
# | epoch   0 |  1315/18000 batches | ms/batch 680.13 | loss  0.15 | valid  0.12
# | epoch   0 |  1320/18000 batches | ms/batch 682.51 | loss  0.11 | valid  0.12
# | epoch   0 |  1325/18000 batches | ms/batch 685.11 | loss  0.13 | valid  0.12
# | epoch   0 |  1330/18000 batches | ms/batch 687.71 | loss  0.12 | valid  0.12
# | epoch   0 |  1335/18000 batches | ms/batch 690.11 | loss  0.10 | valid  0.16
# | epoch   0 |  1340/18000 batches | ms/batch 692.57 | loss  0.18 | valid  0.12
# | epoch   0 |  1345/18000 batches | ms/batch 695.33 | loss  0.15 | valid  0.12
# | epoch   0 |  1350/18000 batches | ms/batch 697.75 | loss  0.14 | valid  0.12
# | epoch   0 |  1355/18000 batches | ms/batch 700.18 | loss  0.14 | valid  0.12
# | epoch   0 |  1360/18000 batches | ms/batch 702.76 | loss  0.14 | valid  0.12
# | epoch   0 |  1365/18000 batches | ms/batch 705.36 | loss  0.12 | valid  0.12
# | epoch   0 |  1370/18000 batches | ms/batch 707.93 | loss  0.13 | valid  0.13
# | epoch   0 |  1375/18000 batches | ms/batch 710.63 | loss  0.14 | valid  0.13
# | epoch   0 |  1380/18000 batches | ms/batch 713.27 | loss  0.11 | valid  0.15
# | epoch   0 |  1385/18000 batches | ms/batch 715.90 | loss  0.14 | valid  0.13
# | epoch   0 |  1390/18000 batches | ms/batch 718.43 | loss  0.17 | valid  0.14
# | epoch   0 |  1395/18000 batches | ms/batch 721.09 | loss  0.16 | valid  0.11
# | epoch   0 |  1400/18000 batches | ms/batch 723.61 | loss  0.13 | valid  0.12
# | epoch   0 |  1405/18000 batches | ms/batch 726.13 | loss  0.15 | valid  0.13
# | epoch   0 |  1410/18000 batches | ms/batch 729.17 | loss  0.14 | valid  0.12
# | epoch   0 |  1415/18000 batches | ms/batch 731.82 | loss  0.12 | valid  0.13
# | epoch   0 |  1420/18000 batches | ms/batch 734.81 | loss  0.15 | valid  0.13
# | epoch   0 |  1425/18000 batches | ms/batch 737.30 | loss  0.15 | valid  0.13
# | epoch   0 |  1430/18000 batches | ms/batch 739.96 | loss  0.16 | valid  0.14
# | epoch   0 |  1435/18000 batches | ms/batch 742.74 | loss  0.16 | valid  0.14
# | epoch   0 |  1440/18000 batches | ms/batch 745.49 | loss  0.14 | valid  0.13
# | epoch   0 |  1445/18000 batches | ms/batch 747.84 | loss  0.12 | valid  0.13
# | epoch   0 |  1450/18000 batches | ms/batch 750.29 | loss  0.14 | valid  0.12
# | epoch   0 |  1455/18000 batches | ms/batch 752.71 | loss  0.14 | valid  0.12
# | epoch   0 |  1460/18000 batches | ms/batch 755.38 | loss  0.12 | valid  0.12
# | epoch   0 |  1465/18000 batches | ms/batch 758.02 | loss  0.13 | valid  0.12
# | epoch   0 |  1470/18000 batches | ms/batch 760.54 | loss  0.15 | valid  0.12
# | epoch   0 |  1475/18000 batches | ms/batch 762.96 | loss  0.15 | valid  0.12
# | epoch   0 |  1480/18000 batches | ms/batch 765.50 | loss  0.14 | valid  0.12
# | epoch   0 |  1485/18000 batches | ms/batch 768.20 | loss  0.14 | valid  0.12
# | epoch   0 |  1490/18000 batches | ms/batch 770.67 | loss  0.13 | valid  0.12
# | epoch   0 |  1495/18000 batches | ms/batch 773.24 | loss  0.13 | valid  0.12
# | epoch   0 |  1500/18000 batches | ms/batch 775.59 | loss  0.13 | valid  0.12
# | epoch   0 |  1505/18000 batches | ms/batch 778.10 | loss  0.12 | valid  0.12
# | epoch   0 |  1510/18000 batches | ms/batch 780.43 | loss  0.15 | valid  0.12
# | epoch   0 |  1515/18000 batches | ms/batch 782.79 | loss  0.18 | valid  0.12
# | epoch   0 |  1520/18000 batches | ms/batch 785.25 | loss  0.13 | valid  0.12
# | epoch   0 |  1525/18000 batches | ms/batch 787.86 | loss  0.12 | valid  0.12
# | epoch   0 |  1530/18000 batches | ms/batch 790.73 | loss  0.14 | valid  0.12
# | epoch   0 |  1535/18000 batches | ms/batch 793.52 | loss  0.16 | valid  0.12
# | epoch   0 |  1540/18000 batches | ms/batch 796.28 | loss  0.14 | valid  0.12
# | epoch   0 |  1545/18000 batches | ms/batch 798.85 | loss  0.15 | valid  0.12
# | epoch   0 |  1550/18000 batches | ms/batch 801.31 | loss  0.15 | valid  0.12
# | epoch   0 |  1555/18000 batches | ms/batch 803.91 | loss  0.15 | valid  0.12
# | epoch   0 |  1560/18000 batches | ms/batch 808.05 | loss  0.14 | valid  0.11
# | epoch   0 |  1565/18000 batches | ms/batch 810.49 | loss  0.13 | valid  0.14
# | epoch   0 |  1570/18000 batches | ms/batch 812.93 | loss  0.14 | valid  0.12
# | epoch   0 |  1575/18000 batches | ms/batch 815.34 | loss  0.15 | valid  0.13
# | epoch   0 |  1580/18000 batches | ms/batch 818.12 | loss  0.17 | valid  0.13
# | epoch   0 |  1585/18000 batches | ms/batch 821.13 | loss  0.14 | valid  0.13
# | epoch   0 |  1590/18000 batches | ms/batch 824.08 | loss  0.11 | valid  0.15
# | epoch   0 |  1595/18000 batches | ms/batch 826.70 | loss  0.12 | valid  0.14
# | epoch   0 |  1600/18000 batches | ms/batch 829.47 | loss  0.14 | valid  0.12
# | epoch   0 |  1605/18000 batches | ms/batch 832.09 | loss  0.15 | valid  0.13
# | epoch   0 |  1610/18000 batches | ms/batch 835.10 | loss  0.10 | valid  0.15
# | epoch   0 |  1615/18000 batches | ms/batch 837.65 | loss  0.13 | valid  0.13
# | epoch   0 |  1620/18000 batches | ms/batch 840.16 | loss  0.09 | valid  0.13
# | epoch   0 |  1625/18000 batches | ms/batch 842.44 | loss  0.14 | valid  0.13
# | epoch   0 |  1630/18000 batches | ms/batch 844.89 | loss  0.13 | valid  0.12
# | epoch   0 |  1635/18000 batches | ms/batch 847.38 | loss  0.13 | valid  0.13
# | epoch   0 |  1640/18000 batches | ms/batch 849.98 | loss  0.14 | valid  0.12
# | epoch   0 |  1645/18000 batches | ms/batch 852.91 | loss  0.12 | valid  0.12
# | epoch   0 |  1650/18000 batches | ms/batch 856.16 | loss  0.15 | valid  0.12
# | epoch   0 |  1655/18000 batches | ms/batch 859.12 | loss  0.18 | valid  0.13
# | epoch   0 |  1660/18000 batches | ms/batch 861.65 | loss  0.17 | valid  0.13
# | epoch   0 |  1665/18000 batches | ms/batch 864.59 | loss  0.13 | valid  0.13
# | epoch   0 |  1670/18000 batches | ms/batch 867.33 | loss  0.14 | valid  0.13
# | epoch   0 |  1675/18000 batches | ms/batch 870.21 | loss  0.13 | valid  0.13
# | epoch   0 |  1680/18000 batches | ms/batch 872.92 | loss  0.14 | valid  0.12
# | epoch   0 |  1685/18000 batches | ms/batch 875.57 | loss  0.12 | valid  0.12
# | epoch   0 |  1690/18000 batches | ms/batch 878.36 | loss  0.13 | valid  0.12
# | epoch   0 |  1695/18000 batches | ms/batch 880.72 | loss  0.14 | valid  0.12
# | epoch   0 |  1700/18000 batches | ms/batch 882.91 | loss  0.16 | valid  0.11
# | epoch   0 |  1705/18000 batches | ms/batch 885.34 | loss  0.14 | valid  0.12
# | epoch   0 |  1710/18000 batches | ms/batch 888.05 | loss  0.14 | valid  0.12
# | epoch   0 |  1715/18000 batches | ms/batch 890.43 | loss  0.14 | valid  0.12
# | epoch   0 |  1720/18000 batches | ms/batch 892.87 | loss  0.14 | valid  0.12
# | epoch   0 |  1725/18000 batches | ms/batch 895.51 | loss  0.12 | valid  0.12
# | epoch   0 |  1730/18000 batches | ms/batch 898.18 | loss  0.14 | valid  0.12
# | epoch   0 |  1735/18000 batches | ms/batch 901.09 | loss  0.14 | valid  0.12
# | epoch   0 |  1740/18000 batches | ms/batch 903.51 | loss  0.16 | valid  0.12
# | epoch   0 |  1745/18000 batches | ms/batch 906.04 | loss  0.12 | valid  0.12
# | epoch   0 |  1750/18000 batches | ms/batch 908.46 | loss  0.14 | valid  0.12
# | epoch   0 |  1755/18000 batches | ms/batch 911.02 | loss  0.12 | valid  0.11
# | epoch   0 |  1760/18000 batches | ms/batch 913.37 | loss  0.14 | valid  0.11
# | epoch   0 |  1765/18000 batches | ms/batch 916.02 | loss  0.14 | valid  0.12
# | epoch   0 |  1770/18000 batches | ms/batch 918.69 | loss  0.15 | valid  0.12
# | epoch   0 |  1775/18000 batches | ms/batch 921.38 | loss  0.16 | valid  0.12
# | epoch   0 |  1780/18000 batches | ms/batch 923.83 | loss  0.15 | valid  0.12
# | epoch   0 |  1785/18000 batches | ms/batch 926.53 | loss  0.13 | valid  0.13
# | epoch   0 |  1790/18000 batches | ms/batch 929.30 | loss  0.11 | valid  0.13
# | epoch   0 |  1795/18000 batches | ms/batch 931.82 | loss  0.14 | valid  0.15
# | epoch   0 |  1800/18000 batches | ms/batch 934.41 | loss  0.13 | valid  0.14
# | epoch   0 |  1805/18000 batches | ms/batch 936.76 | loss  0.16 | valid  0.14
# | epoch   0 |  1810/18000 batches | ms/batch 939.42 | loss  0.13 | valid  0.12
# | epoch   0 |  1815/18000 batches | ms/batch 941.89 | loss  0.14 | valid  0.13
# | epoch   0 |  1820/18000 batches | ms/batch 944.41 | loss  0.15 | valid  0.12
# | epoch   0 |  1825/18000 batches | ms/batch 947.00 | loss  0.13 | valid  0.13
# | epoch   0 |  1830/18000 batches | ms/batch 949.54 | loss  0.14 | valid  0.13
# | epoch   0 |  1835/18000 batches | ms/batch 951.94 | loss  0.13 | valid  0.12
# | epoch   0 |  1840/18000 batches | ms/batch 954.37 | loss  0.14 | valid  0.12
# | epoch   0 |  1845/18000 batches | ms/batch 956.69 | loss  0.17 | valid  0.12
# | epoch   0 |  1850/18000 batches | ms/batch 959.14 | loss  0.16 | valid  0.13
# | epoch   0 |  1855/18000 batches | ms/batch 961.65 | loss  0.13 | valid  0.13
# | epoch   0 |  1860/18000 batches | ms/batch 964.14 | loss  0.13 | valid  0.13
# | epoch   0 |  1865/18000 batches | ms/batch 966.83 | loss  0.13 | valid  0.12
# | epoch   0 |  1870/18000 batches | ms/batch 969.84 | loss  0.12 | valid  0.12
# | epoch   0 |  1875/18000 batches | ms/batch 972.72 | loss  0.11 | valid  0.12
# | epoch   0 |  1880/18000 batches | ms/batch 975.24 | loss  0.12 | valid  0.12
# | epoch   0 |  1885/18000 batches | ms/batch 977.84 | loss  0.13 | valid  0.12
# | epoch   0 |  1890/18000 batches | ms/batch 980.68 | loss  0.13 | valid  0.12
# | epoch   0 |  1895/18000 batches | ms/batch 983.57 | loss  0.14 | valid  0.12
# | epoch   0 |  1900/18000 batches | ms/batch 986.45 | loss  0.14 | valid  0.12
# | epoch   0 |  1905/18000 batches | ms/batch 989.28 | loss  0.15 | valid  0.12
# | epoch   0 |  1910/18000 batches | ms/batch 992.42 | loss  0.14 | valid  0.11
# | epoch   0 |  1915/18000 batches | ms/batch 994.93 | loss  0.16 | valid  0.12
# | epoch   0 |  1920/18000 batches | ms/batch 997.53 | loss  0.14 | valid  0.12
# | epoch   0 |  1925/18000 batches | ms/batch 1000.08 | loss  0.15 | valid  0.13
# | epoch   0 |  1930/18000 batches | ms/batch 1002.49 | loss  0.14 | valid  0.13
# | epoch   0 |  1935/18000 batches | ms/batch 1005.07 | loss  0.12 | valid  0.12
# | epoch   0 |  1940/18000 batches | ms/batch 1007.61 | loss  0.15 | valid  0.12
# | epoch   0 |  1945/18000 batches | ms/batch 1010.07 | loss  0.15 | valid  0.12
# | epoch   0 |  1950/18000 batches | ms/batch 1012.57 | loss  0.13 | valid  0.12
# | epoch   0 |  1955/18000 batches | ms/batch 1015.24 | loss  0.11 | valid  0.13
# | epoch   0 |  1960/18000 batches | ms/batch 1017.87 | loss  0.13 | valid  0.13
# | epoch   0 |  1965/18000 batches | ms/batch 1020.73 | loss  0.11 | valid  0.13
# | epoch   0 |  1970/18000 batches | ms/batch 1023.56 | loss  0.12 | valid  0.12
# | epoch   0 |  1975/18000 batches | ms/batch 1026.09 | loss  0.15 | valid  0.12
# | epoch   0 |  1980/18000 batches | ms/batch 1028.50 | loss  0.12 | valid  0.12
# | epoch   0 |  1985/18000 batches | ms/batch 1030.81 | loss  0.13 | valid  0.12
# | epoch   0 |  1990/18000 batches | ms/batch 1033.25 | loss  0.15 | valid  0.12
# | epoch   0 |  1995/18000 batches | ms/batch 1035.82 | loss  0.16 | valid  0.13
# | epoch   0 |  2000/18000 batches | ms/batch 1038.28 | loss  0.13 | valid  0.13
# | epoch   0 |  2005/18000 batches | ms/batch 1044.46 | loss  0.14 | valid  0.13
# | epoch   0 |  2010/18000 batches | ms/batch 1047.24 | loss  0.15 | valid  0.12
# | epoch   0 |  2015/18000 batches | ms/batch 1050.12 | loss  0.12 | valid  0.13
# | epoch   0 |  2020/18000 batches | ms/batch 1052.82 | loss  0.14 | valid  0.12
# | epoch   0 |  2025/18000 batches | ms/batch 1055.70 | loss  0.13 | valid  0.12
# | epoch   0 |  2030/18000 batches | ms/batch 1058.40 | loss  0.14 | valid  0.12
# | epoch   0 |  2035/18000 batches | ms/batch 1061.04 | loss  0.12 | valid  0.11
# | epoch   0 |  2040/18000 batches | ms/batch 1063.79 | loss  0.15 | valid  0.12
# | epoch   0 |  2045/18000 batches | ms/batch 1066.63 | loss  0.14 | valid  0.12
# | epoch   0 |  2050/18000 batches | ms/batch 1069.24 | loss  0.12 | valid  0.12
# | epoch   0 |  2055/18000 batches | ms/batch 1071.78 | loss  0.14 | valid  0.12
# | epoch   0 |  2060/18000 batches | ms/batch 1074.48 | loss  0.12 | valid  0.13
# | epoch   0 |  2065/18000 batches | ms/batch 1077.26 | loss  0.12 | valid  0.14
# | epoch   0 |  2070/18000 batches | ms/batch 1079.84 | loss  0.16 | valid  0.13
# | epoch   0 |  2075/18000 batches | ms/batch 1082.42 | loss  0.13 | valid  0.12
# | epoch   0 |  2080/18000 batches | ms/batch 1084.85 | loss  0.15 | valid  0.12
# | epoch   0 |  2085/18000 batches | ms/batch 1087.29 | loss  0.13 | valid  0.12
# | epoch   0 |  2090/18000 batches | ms/batch 1090.29 | loss  0.14 | valid  0.12
# | epoch   0 |  2095/18000 batches | ms/batch 1092.80 | loss  0.15 | valid  0.12
# | epoch   0 |  2100/18000 batches | ms/batch 1095.17 | loss  0.15 | valid  0.12
# | epoch   0 |  2105/18000 batches | ms/batch 1097.66 | loss  0.13 | valid  0.12
# | epoch   0 |  2110/18000 batches | ms/batch 1100.14 | loss  0.14 | valid  0.12
# | epoch   0 |  2115/18000 batches | ms/batch 1102.68 | loss  0.14 | valid  0.12
# | epoch   0 |  2120/18000 batches | ms/batch 1105.24 | loss  0.11 | valid  0.11
# | epoch   0 |  2125/18000 batches | ms/batch 1107.67 | loss  0.14 | valid  0.11
# | epoch   0 |  2130/18000 batches | ms/batch 1110.18 | loss  0.13 | valid  0.11
# | epoch   0 |  2135/18000 batches | ms/batch 1112.83 | loss  0.13 | valid  0.11
# | epoch   0 |  2140/18000 batches | ms/batch 1115.38 | loss  0.14 | valid  0.11
# | epoch   0 |  2145/18000 batches | ms/batch 1117.93 | loss  0.14 | valid  0.11
# | epoch   0 |  2150/18000 batches | ms/batch 1120.50 | loss  0.12 | valid  0.11
# | epoch   0 |  2155/18000 batches | ms/batch 1122.91 | loss  0.14 | valid  0.11
# | epoch   0 |  2160/18000 batches | ms/batch 1125.44 | loss  0.12 | valid  0.12
# | epoch   0 |  2165/18000 batches | ms/batch 1128.27 | loss  0.10 | valid  0.14
# | epoch   0 |  2170/18000 batches | ms/batch 1130.80 | loss  0.15 | valid  0.12
# | epoch   0 |  2175/18000 batches | ms/batch 1133.55 | loss  0.14 | valid  0.12
# | epoch   0 |  2180/18000 batches | ms/batch 1136.34 | loss  0.10 | valid  0.14
# | epoch   0 |  2185/18000 batches | ms/batch 1139.04 | loss  0.12 | valid  0.14
# | epoch   0 |  2190/18000 batches | ms/batch 1141.88 | loss  0.12 | valid  0.12
# | epoch   0 |  2195/18000 batches | ms/batch 1144.78 | loss  0.14 | valid  0.12
# | epoch   0 |  2200/18000 batches | ms/batch 1147.63 | loss  0.15 | valid  0.12
# | epoch   0 |  2205/18000 batches | ms/batch 1150.30 | loss  0.15 | valid  0.12
# | epoch   0 |  2210/18000 batches | ms/batch 1152.94 | loss  0.16 | valid  0.11
# | epoch   0 |  2215/18000 batches | ms/batch 1155.49 | loss  0.16 | valid  0.11
# | epoch   0 |  2220/18000 batches | ms/batch 1158.03 | loss  0.15 | valid  0.12
# | epoch   0 |  2225/18000 batches | ms/batch 1160.58 | loss  0.14 | valid  0.13
# | epoch   0 |  2230/18000 batches | ms/batch 1163.07 | loss  0.14 | valid  0.12
# | epoch   0 |  2235/18000 batches | ms/batch 1165.71 | loss  0.13 | valid  0.13
# | epoch   0 |  2240/18000 batches | ms/batch 1168.56 | loss  0.10 | valid  0.12
# | epoch   0 |  2245/18000 batches | ms/batch 1171.17 | loss  0.12 | valid  0.12
# | epoch   0 |  2250/18000 batches | ms/batch 1173.71 | loss  0.14 | valid  0.12
# | epoch   0 |  2255/18000 batches | ms/batch 1176.43 | loss  0.14 | valid  0.12
# | epoch   0 |  2260/18000 batches | ms/batch 1178.96 | loss  0.13 | valid  0.12
# | epoch   0 |  2265/18000 batches | ms/batch 1181.77 | loss  0.17 | valid  0.12
# | epoch   0 |  2270/18000 batches | ms/batch 1184.47 | loss  0.13 | valid  0.12
# | epoch   0 |  2275/18000 batches | ms/batch 1186.92 | loss  0.13 | valid  0.12
# | epoch   0 |  2280/18000 batches | ms/batch 1189.48 | loss  0.14 | valid  0.12
# | epoch   0 |  2285/18000 batches | ms/batch 1192.10 | loss  0.10 | valid  0.12
# | epoch   0 |  2290/18000 batches | ms/batch 1194.60 | loss  0.12 | valid  0.12
# | epoch   0 |  2295/18000 batches | ms/batch 1197.17 | loss  0.11 | valid  0.12
# | epoch   0 |  2300/18000 batches | ms/batch 1200.22 | loss  0.11 | valid  0.13
# | epoch   0 |  2305/18000 batches | ms/batch 1202.61 | loss  0.09 | valid  0.12
# | epoch   0 |  2310/18000 batches | ms/batch 1205.06 | loss  0.12 | valid  0.12
# | epoch   0 |  2315/18000 batches | ms/batch 1207.80 | loss  0.13 | valid  0.12
# | epoch   0 |  2320/18000 batches | ms/batch 1210.34 | loss  0.16 | valid  0.12
# | epoch   0 |  2325/18000 batches | ms/batch 1212.75 | loss  0.13 | valid  0.12
# | epoch   0 |  2330/18000 batches | ms/batch 1217.16 | loss  0.15 | valid  0.11
# | epoch   0 |  2335/18000 batches | ms/batch 1219.78 | loss  0.12 | valid  0.12
# | epoch   0 |  2340/18000 batches | ms/batch 1222.23 | loss  0.15 | valid  0.12
# | epoch   0 |  2345/18000 batches | ms/batch 1224.63 | loss  0.16 | valid  0.12
# | epoch   0 |  2350/18000 batches | ms/batch 1227.22 | loss  0.13 | valid  0.12
# | epoch   0 |  2355/18000 batches | ms/batch 1229.57 | loss  0.14 | valid  0.12
# | epoch   0 |  2360/18000 batches | ms/batch 1232.24 | loss  0.14 | valid  0.12
# | epoch   0 |  2365/18000 batches | ms/batch 1234.97 | loss  0.16 | valid  0.12
# | epoch   0 |  2370/18000 batches | ms/batch 1237.50 | loss  0.12 | valid  0.12
# | epoch   0 |  2375/18000 batches | ms/batch 1240.13 | loss  0.14 | valid  0.12
# | epoch   0 |  2380/18000 batches | ms/batch 1242.86 | loss  0.15 | valid  0.12
# | epoch   0 |  2385/18000 batches | ms/batch 1245.91 | loss  0.14 | valid  0.12
# | epoch   0 |  2390/18000 batches | ms/batch 1248.84 | loss  0.14 | valid  0.12
# | epoch   0 |  2395/18000 batches | ms/batch 1251.56 | loss  0.13 | valid  0.11
# | epoch   0 |  2400/18000 batches | ms/batch 1254.11 | loss  0.13 | valid  0.11
# | epoch   0 |  2405/18000 batches | ms/batch 1256.81 | loss  0.12 | valid  0.12
# | epoch   0 |  2410/18000 batches | ms/batch 1259.41 | loss  0.12 | valid  0.13
# | epoch   0 |  2415/18000 batches | ms/batch 1262.05 | loss  0.13 | valid  0.13
# | epoch   0 |  2420/18000 batches | ms/batch 1264.45 | loss  0.12 | valid  0.11
# | epoch   0 |  2425/18000 batches | ms/batch 1266.98 | loss  0.11 | valid  0.11
# | epoch   0 |  2430/18000 batches | ms/batch 1269.57 | loss  0.12 | valid  0.11
# | epoch   0 |  2435/18000 batches | ms/batch 1272.01 | loss  0.13 | valid  0.13
# | epoch   0 |  2440/18000 batches | ms/batch 1274.79 | loss  0.14 | valid  0.13
# | epoch   0 |  2445/18000 batches | ms/batch 1277.60 | loss  0.16 | valid  0.13
# | epoch   0 |  2450/18000 batches | ms/batch 1280.29 | loss  0.15 | valid  0.12
# | epoch   0 |  2455/18000 batches | ms/batch 1282.86 | loss  0.14 | valid  0.12
# | epoch   0 |  2460/18000 batches | ms/batch 1285.20 | loss  0.13 | valid  0.12
# | epoch   0 |  2465/18000 batches | ms/batch 1287.48 | loss  0.15 | valid  0.12
# | epoch   0 |  2470/18000 batches | ms/batch 1289.86 | loss  0.14 | valid  0.13
# | epoch   0 |  2475/18000 batches | ms/batch 1292.29 | loss  0.14 | valid  0.13
# | epoch   0 |  2480/18000 batches | ms/batch 1294.78 | loss  0.15 | valid  0.13
# | epoch   0 |  2485/18000 batches | ms/batch 1297.37 | loss  0.16 | valid  0.13
# | epoch   0 |  2490/18000 batches | ms/batch 1299.79 | loss  0.14 | valid  0.12
# | epoch   0 |  2495/18000 batches | ms/batch 1302.22 | loss  0.13 | valid  0.11
# | epoch   0 |  2500/18000 batches | ms/batch 1304.75 | loss  0.15 | valid  0.11
# | epoch   0 |  2505/18000 batches | ms/batch 1307.39 | loss  0.16 | valid  0.12
# | epoch   0 |  2510/18000 batches | ms/batch 1310.18 | loss  0.12 | valid  0.12
# | epoch   0 |  2515/18000 batches | ms/batch 1312.68 | loss  0.13 | valid  0.12
# | epoch   0 |  2520/18000 batches | ms/batch 1315.27 | loss  0.13 | valid  0.12
# | epoch   0 |  2525/18000 batches | ms/batch 1317.68 | loss  0.14 | valid  0.12
# | epoch   0 |  2530/18000 batches | ms/batch 1320.09 | loss  0.13 | valid  0.12
# | epoch   0 |  2535/18000 batches | ms/batch 1322.99 | loss  0.14 | valid  0.12
# | epoch   0 |  2540/18000 batches | ms/batch 1325.27 | loss  0.14 | valid  0.12
# | epoch   0 |  2545/18000 batches | ms/batch 1327.47 | loss  0.14 | valid  0.11
# | epoch   0 |  2550/18000 batches | ms/batch 1330.15 | loss  0.13 | valid  0.12
# | epoch   0 |  2555/18000 batches | ms/batch 1332.98 | loss  0.14 | valid  0.11
# | epoch   0 |  2560/18000 batches | ms/batch 1335.67 | loss  0.13 | valid  0.15
# | epoch   0 |  2565/18000 batches | ms/batch 1338.22 | loss  0.13 | valid  0.15
# | epoch   0 |  2570/18000 batches | ms/batch 1340.91 | loss  0.10 | valid  0.12
# | epoch   0 |  2575/18000 batches | ms/batch 1343.34 | loss  0.11 | valid  0.13
# | epoch   0 |  2580/18000 batches | ms/batch 1346.05 | loss  0.12 | valid  0.14
# | epoch   0 |  2585/18000 batches | ms/batch 1348.57 | loss  0.13 | valid  0.12
# | epoch   0 |  2590/18000 batches | ms/batch 1351.02 | loss  0.12 | valid  0.12
# | epoch   0 |  2595/18000 batches | ms/batch 1353.31 | loss  0.14 | valid  0.13
# | epoch   0 |  2600/18000 batches | ms/batch 1355.61 | loss  0.15 | valid  0.12
# | epoch   0 |  2605/18000 batches | ms/batch 1358.16 | loss  0.15 | valid  0.12
# | epoch   0 |  2610/18000 batches | ms/batch 1360.81 | loss  0.13 | valid  0.12
# | epoch   0 |  2615/18000 batches | ms/batch 1363.48 | loss  0.13 | valid  0.12
# | epoch   0 |  2620/18000 batches | ms/batch 1366.08 | loss  0.15 | valid  0.12
# | epoch   0 |  2625/18000 batches | ms/batch 1368.45 | loss  0.14 | valid  0.12
# | epoch   0 |  2630/18000 batches | ms/batch 1370.83 | loss  0.15 | valid  0.13
# | epoch   0 |  2635/18000 batches | ms/batch 1373.34 | loss  0.12 | valid  0.13
# | epoch   0 |  2640/18000 batches | ms/batch 1376.15 | loss  0.11 | valid  0.13
# | epoch   0 |  2645/18000 batches | ms/batch 1378.58 | loss  0.13 | valid  0.13
# | epoch   0 |  2650/18000 batches | ms/batch 1381.17 | loss  0.12 | valid  0.13
# | epoch   0 |  2655/18000 batches | ms/batch 1383.74 | loss  0.14 | valid  0.13
# | epoch   0 |  2660/18000 batches | ms/batch 1386.35 | loss  0.16 | valid  0.13
# | epoch   0 |  2665/18000 batches | ms/batch 1388.68 | loss  0.17 | valid  0.12
# | epoch   0 |  2670/18000 batches | ms/batch 1391.51 | loss  0.15 | valid  0.13
# | epoch   0 |  2675/18000 batches | ms/batch 1394.26 | loss  0.12 | valid  0.13
# | epoch   0 |  2680/18000 batches | ms/batch 1396.70 | loss  0.11 | valid  0.13
# | epoch   0 |  2685/18000 batches | ms/batch 1399.37 | loss  0.13 | valid  0.12
# | epoch   0 |  2690/18000 batches | ms/batch 1402.07 | loss  0.12 | valid  0.14
# | epoch   0 |  2695/18000 batches | ms/batch 1404.61 | loss  0.14 | valid  0.13
# | epoch   0 |  2700/18000 batches | ms/batch 1407.35 | loss  0.15 | valid  0.12
# | epoch   0 |  2705/18000 batches | ms/batch 1410.11 | loss  0.15 | valid  0.12
# | epoch   0 |  2710/18000 batches | ms/batch 1412.58 | loss  0.13 | valid  0.12
# | epoch   0 |  2715/18000 batches | ms/batch 1415.26 | loss  0.12 | valid  0.12
# | epoch   0 |  2720/18000 batches | ms/batch 1417.84 | loss  0.13 | valid  0.12
# | epoch   0 |  2725/18000 batches | ms/batch 1420.41 | loss  0.14 | valid  0.12
# | epoch   0 |  2730/18000 batches | ms/batch 1422.92 | loss  0.14 | valid  0.12
# | epoch   0 |  2735/18000 batches | ms/batch 1425.46 | loss  0.15 | valid  0.12
# | epoch   0 |  2740/18000 batches | ms/batch 1428.05 | loss  0.11 | valid  0.13
# | epoch   0 |  2745/18000 batches | ms/batch 1430.57 | loss  0.14 | valid  0.13
# | epoch   0 |  2750/18000 batches | ms/batch 1433.26 | loss  0.14 | valid  0.12
# | epoch   0 |  2755/18000 batches | ms/batch 1435.93 | loss  0.15 | valid  0.12
# | epoch   0 |  2760/18000 batches | ms/batch 1438.46 | loss  0.13 | valid  0.11
# | epoch   0 |  2765/18000 batches | ms/batch 1440.97 | loss  0.15 | valid  0.12
# | epoch   0 |  2770/18000 batches | ms/batch 1443.37 | loss  0.13 | valid  0.11
# | epoch   0 |  2775/18000 batches | ms/batch 1447.91 | loss  0.11 | valid  0.11
# | epoch   0 |  2780/18000 batches | ms/batch 1450.35 | loss  0.15 | valid  0.12
# | epoch   0 |  2785/18000 batches | ms/batch 1453.12 | loss  0.14 | valid  0.12
# | epoch   0 |  2790/18000 batches | ms/batch 1455.54 | loss  0.16 | valid  0.12
# | epoch   0 |  2795/18000 batches | ms/batch 1457.93 | loss  0.14 | valid  0.12
# | epoch   0 |  2800/18000 batches | ms/batch 1460.17 | loss  0.14 | valid  0.12
# | epoch   0 |  2805/18000 batches | ms/batch 1462.89 | loss  0.12 | valid  0.13
# | epoch   0 |  2810/18000 batches | ms/batch 1465.62 | loss  0.12 | valid  0.12
# | epoch   0 |  2815/18000 batches | ms/batch 1468.04 | loss  0.13 | valid  0.12
# | epoch   0 |  2820/18000 batches | ms/batch 1470.41 | loss  0.14 | valid  0.12
# | epoch   0 |  2825/18000 batches | ms/batch 1472.82 | loss  0.15 | valid  0.12
# | epoch   0 |  2830/18000 batches | ms/batch 1475.12 | loss  0.13 | valid  0.13
# | epoch   0 |  2835/18000 batches | ms/batch 1477.70 | loss  0.12 | valid  0.13
# | epoch   0 |  2840/18000 batches | ms/batch 1480.28 | loss  0.15 | valid  0.12
# | epoch   0 |  2845/18000 batches | ms/batch 1482.91 | loss  0.14 | valid  0.12
# | epoch   0 |  2850/18000 batches | ms/batch 1485.39 | loss  0.14 | valid  0.12
# | epoch   0 |  2855/18000 batches | ms/batch 1488.11 | loss  0.12 | valid  0.12
# | epoch   0 |  2860/18000 batches | ms/batch 1490.98 | loss  0.12 | valid  0.13
# | epoch   0 |  2865/18000 batches | ms/batch 1493.58 | loss  0.14 | valid  0.13
# | epoch   0 |  2870/18000 batches | ms/batch 1495.95 | loss  0.15 | valid  0.13
# | epoch   0 |  2875/18000 batches | ms/batch 1498.36 | loss  0.14 | valid  0.12
# | epoch   0 |  2880/18000 batches | ms/batch 1500.88 | loss  0.12 | valid  0.11
# | epoch   0 |  2885/18000 batches | ms/batch 1503.29 | loss  0.12 | valid  0.11
# | epoch   0 |  2890/18000 batches | ms/batch 1505.57 | loss  0.13 | valid  0.12
# | epoch   0 |  2895/18000 batches | ms/batch 1507.99 | loss  0.14 | valid  0.12
# | epoch   0 |  2900/18000 batches | ms/batch 1510.58 | loss  0.14 | valid  0.12
# | epoch   0 |  2905/18000 batches | ms/batch 1513.34 | loss  0.17 | valid  0.12
# | epoch   0 |  2910/18000 batches | ms/batch 1515.98 | loss  0.14 | valid  0.12
# | epoch   0 |  2915/18000 batches | ms/batch 1518.35 | loss  0.13 | valid  0.13
# | epoch   0 |  2920/18000 batches | ms/batch 1520.78 | loss  0.15 | valid  0.13
# | epoch   0 |  2925/18000 batches | ms/batch 1523.37 | loss  0.12 | valid  0.12
# | epoch   0 |  2930/18000 batches | ms/batch 1525.68 | loss  0.13 | valid  0.12
# | epoch   0 |  2935/18000 batches | ms/batch 1528.02 | loss  0.14 | valid  0.13
# | epoch   0 |  2940/18000 batches | ms/batch 1530.45 | loss  0.15 | valid  0.13
# | epoch   0 |  2945/18000 batches | ms/batch 1533.10 | loss  0.14 | valid  0.12
# | epoch   0 |  2950/18000 batches | ms/batch 1535.80 | loss  0.14 | valid  0.12
# | epoch   0 |  2955/18000 batches | ms/batch 1538.13 | loss  0.14 | valid  0.12
# | epoch   0 |  2960/18000 batches | ms/batch 1540.52 | loss  0.15 | valid  0.12
# | epoch   0 |  2965/18000 batches | ms/batch 1543.15 | loss  0.13 | valid  0.13
# | epoch   0 |  2970/18000 batches | ms/batch 1545.54 | loss  0.15 | valid  0.13
# | epoch   0 |  2975/18000 batches | ms/batch 1548.07 | loss  0.12 | valid  0.12
# | epoch   0 |  2980/18000 batches | ms/batch 1550.85 | loss  0.11 | valid  0.13
# | epoch   0 |  2985/18000 batches | ms/batch 1553.56 | loss  0.13 | valid  0.11
# | epoch   0 |  2990/18000 batches | ms/batch 1556.18 | loss  0.11 | valid  0.11
# | epoch   0 |  2995/18000 batches | ms/batch 1558.83 | loss  0.13 | valid  0.11
# | epoch   0 |  3000/18000 batches | ms/batch 1561.38 | loss  0.15 | valid  0.12
# | epoch   0 |  3005/18000 batches | ms/batch 1563.96 | loss  0.13 | valid  0.11
# | epoch   0 |  3010/18000 batches | ms/batch 1566.52 | loss  0.15 | valid  0.11
# | epoch   0 |  3015/18000 batches | ms/batch 1569.23 | loss  0.14 | valid  0.11
# | epoch   0 |  3020/18000 batches | ms/batch 1571.85 | loss  0.14 | valid  0.12
# | epoch   0 |  3025/18000 batches | ms/batch 1574.34 | loss  0.15 | valid  0.12
# ...
# | epoch   0 | 17010/18000 batches | ms/batch 8796.65 | loss  0.13 | valid  0.12
# | epoch   0 | 17015/18000 batches | ms/batch 8799.15 | loss  0.12 | valid  0.12
# | epoch   0 | 17020/18000 batches | ms/batch 8801.80 | loss  0.08 | valid  0.12
# | epoch   0 | 17025/18000 batches | ms/batch 8804.51 | loss  0.10 | valid  0.12
# | epoch   0 | 17030/18000 batches | ms/batch 8807.05 | loss  0.14 | valid  0.12
# | epoch   0 | 17035/18000 batches | ms/batch 8809.40 | loss  0.14 | valid  0.12
# | epoch   0 | 17040/18000 batches | ms/batch 8811.92 | loss  0.13 | valid  0.12
# | epoch   0 | 17045/18000 batches | ms/batch 8814.87 | loss  0.13 | valid  0.12
# | epoch   0 | 17050/18000 batches | ms/batch 8817.36 | loss  0.15 | valid  0.12
# | epoch   0 | 17055/18000 batches | ms/batch 8819.69 | loss  0.12 | valid  0.12
# | epoch   0 | 17060/18000 batches | ms/batch 8822.05 | loss  0.09 | valid  0.12
# | epoch   0 | 17065/18000 batches | ms/batch 8824.30 | loss  0.16 | valid  0.12
# | epoch   0 | 17070/18000 batches | ms/batch 8826.76 | loss  0.15 | valid  0.12
# | epoch   0 | 17075/18000 batches | ms/batch 8829.37 | loss  0.11 | valid  0.12
# | epoch   0 | 17080/18000 batches | ms/batch 8832.01 | loss  0.13 | valid  0.12
# | epoch   0 | 17085/18000 batches | ms/batch 8834.60 | loss  0.10 | valid  0.12
# | epoch   0 | 17090/18000 batches | ms/batch 8837.01 | loss  0.12 | valid  0.12
# | epoch   0 | 17095/18000 batches | ms/batch 8839.33 | loss  0.14 | valid  0.12
# | epoch   0 | 17100/18000 batches | ms/batch 8841.90 | loss  0.13 | valid  0.12
# | epoch   0 | 17105/18000 batches | ms/batch 8844.32 | loss  0.15 | valid  0.12
# | epoch   0 | 17110/18000 batches | ms/batch 8846.80 | loss  0.13 | valid  0.12
# | epoch   0 | 17115/18000 batches | ms/batch 8849.27 | loss  0.13 | valid  0.12
# | epoch   0 | 17120/18000 batches | ms/batch 8851.85 | loss  0.14 | valid  0.12
# | epoch   0 | 17125/18000 batches | ms/batch 8854.46 | loss  0.14 | valid  0.12
# | epoch   0 | 17130/18000 batches | ms/batch 8857.06 | loss  0.14 | valid  0.12
# | epoch   0 | 17135/18000 batches | ms/batch 8859.62 | loss  0.13 | valid  0.12
# | epoch   0 | 17140/18000 batches | ms/batch 8862.24 | loss  0.16 | valid  0.12
# | epoch   0 | 17145/18000 batches | ms/batch 8864.67 | loss  0.13 | valid  0.12
# | epoch   0 | 17150/18000 batches | ms/batch 8867.05 | loss  0.12 | valid  0.12
# | epoch   0 | 17155/18000 batches | ms/batch 8869.75 | loss  0.13 | valid  0.12
# | epoch   0 | 17160/18000 batches | ms/batch 8872.31 | loss  0.13 | valid  0.12
# | epoch   0 | 17165/18000 batches | ms/batch 8874.74 | loss  0.15 | valid  0.12
# | epoch   0 | 17170/18000 batches | ms/batch 8877.13 | loss  0.15 | valid  0.12
# | epoch   0 | 17175/18000 batches | ms/batch 8879.52 | loss  0.13 | valid  0.12
# | epoch   0 | 17180/18000 batches | ms/batch 8882.11 | loss  0.13 | valid  0.13
# | epoch   0 | 17185/18000 batches | ms/batch 8884.50 | loss  0.12 | valid  0.12
# | epoch   0 | 17190/18000 batches | ms/batch 8887.08 | loss  0.15 | valid  0.12
# | epoch   0 | 17195/18000 batches | ms/batch 8889.52 | loss  0.15 | valid  0.12
# | epoch   0 | 17200/18000 batches | ms/batch 8892.07 | loss  0.11 | valid  0.12
# | epoch   0 | 17205/18000 batches | ms/batch 8894.57 | loss  0.13 | valid  0.12
# | epoch   0 | 17210/18000 batches | ms/batch 8897.01 | loss  0.10 | valid  0.12
# | epoch   0 | 17215/18000 batches | ms/batch 8899.49 | loss  0.11 | valid  0.12
# | epoch   0 | 17220/18000 batches | ms/batch 8901.85 | loss  0.15 | valid  0.12
# | epoch   0 | 17225/18000 batches | ms/batch 8904.31 | loss  0.12 | valid  0.12
# | epoch   0 | 17230/18000 batches | ms/batch 8907.07 | loss  0.13 | valid  0.12
# | epoch   0 | 17235/18000 batches | ms/batch 8909.78 | loss  0.12 | valid  0.12
# | epoch   0 | 17240/18000 batches | ms/batch 8912.31 | loss  0.13 | valid  0.12
# | epoch   0 | 17245/18000 batches | ms/batch 8914.92 | loss  0.13 | valid  0.12
# | epoch   0 | 17250/18000 batches | ms/batch 8917.70 | loss  0.12 | valid  0.12
# | epoch   0 | 17255/18000 batches | ms/batch 8920.39 | loss  0.15 | valid  0.12
# | epoch   0 | 17260/18000 batches | ms/batch 8922.96 | loss  0.14 | valid  0.12
# | epoch   0 | 17265/18000 batches | ms/batch 8925.37 | loss  0.12 | valid  0.12
# | epoch   0 | 17270/18000 batches | ms/batch 8927.99 | loss  0.13 | valid  0.12
# | epoch   0 | 17275/18000 batches | ms/batch 8930.88 | loss  0.12 | valid  0.12
# | epoch   0 | 17280/18000 batches | ms/batch 8933.52 | loss  0.11 | valid  0.12
# | epoch   0 | 17285/18000 batches | ms/batch 8936.15 | loss  0.14 | valid  0.12
# | epoch   0 | 17290/18000 batches | ms/batch 8938.74 | loss  0.11 | valid  0.12
# | epoch   0 | 17295/18000 batches | ms/batch 8941.32 | loss  0.11 | valid  0.12
# | epoch   0 | 17300/18000 batches | ms/batch 8943.74 | loss  0.15 | valid  0.12
# | epoch   0 | 17305/18000 batches | ms/batch 8946.33 | loss  0.14 | valid  0.12
# | epoch   0 | 17310/18000 batches | ms/batch 8949.05 | loss  0.12 | valid  0.12
# | epoch   0 | 17315/18000 batches | ms/batch 8951.73 | loss  0.12 | valid  0.12
# | epoch   0 | 17320/18000 batches | ms/batch 8954.16 | loss  0.12 | valid  0.12
# | epoch   0 | 17325/18000 batches | ms/batch 8956.88 | loss  0.13 | valid  0.12
# | epoch   0 | 17330/18000 batches | ms/batch 8959.40 | loss  0.16 | valid  0.12
# | epoch   0 | 17335/18000 batches | ms/batch 8961.63 | loss  0.13 | valid  0.12
# | epoch   0 | 17340/18000 batches | ms/batch 8964.28 | loss  0.12 | valid  0.12
# | epoch   0 | 17345/18000 batches | ms/batch 8966.75 | loss  0.14 | valid  0.12
# | epoch   0 | 17350/18000 batches | ms/batch 8969.44 | loss  0.14 | valid  0.12
# | epoch   0 | 17355/18000 batches | ms/batch 8971.93 | loss  0.13 | valid  0.12
# | epoch   0 | 17360/18000 batches | ms/batch 8974.43 | loss  0.12 | valid  0.12
# | epoch   0 | 17365/18000 batches | ms/batch 8978.97 | loss  0.11 | valid  0.12
# | epoch   0 | 17370/18000 batches | ms/batch 8981.59 | loss  0.11 | valid  0.12
# | epoch   0 | 17375/18000 batches | ms/batch 8984.27 | loss  0.12 | valid  0.12
# | epoch   0 | 17380/18000 batches | ms/batch 8986.75 | loss  0.16 | valid  0.12
# | epoch   0 | 17385/18000 batches | ms/batch 8989.18 | loss  0.13 | valid  0.12
# | epoch   0 | 17390/18000 batches | ms/batch 8991.66 | loss  0.14 | valid  0.12
# | epoch   0 | 17395/18000 batches | ms/batch 8994.13 | loss  0.12 | valid  0.12
# | epoch   0 | 17400/18000 batches | ms/batch 8996.72 | loss  0.14 | valid  0.12
# | epoch   0 | 17405/18000 batches | ms/batch 8999.16 | loss  0.12 | valid  0.12
# | epoch   0 | 17410/18000 batches | ms/batch 9001.80 | loss  0.14 | valid  0.12
# | epoch   0 | 17415/18000 batches | ms/batch 9004.40 | loss  0.13 | valid  0.12
# | epoch   0 | 17420/18000 batches | ms/batch 9006.94 | loss  0.10 | valid  0.12
# | epoch   0 | 17425/18000 batches | ms/batch 9009.18 | loss  0.13 | valid  0.12
# | epoch   0 | 17430/18000 batches | ms/batch 9011.48 | loss  0.13 | valid  0.12
# | epoch   0 | 17435/18000 batches | ms/batch 9013.95 | loss  0.12 | valid  0.12
# | epoch   0 | 17440/18000 batches | ms/batch 9016.31 | loss  0.14 | valid  0.12
# | epoch   0 | 17445/18000 batches | ms/batch 9018.70 | loss  0.16 | valid  0.13
# | epoch   0 | 17450/18000 batches | ms/batch 9021.29 | loss  0.14 | valid  0.13
# | epoch   0 | 17455/18000 batches | ms/batch 9024.16 | loss  0.14 | valid  0.13
# | epoch   0 | 17460/18000 batches | ms/batch 9026.64 | loss  0.12 | valid  0.12
# | epoch   0 | 17465/18000 batches | ms/batch 9028.93 | loss  0.09 | valid  0.12
# | epoch   0 | 17470/18000 batches | ms/batch 9031.37 | loss  0.12 | valid  0.13
# | epoch   0 | 17475/18000 batches | ms/batch 9033.97 | loss  0.12 | valid  0.12
# | epoch   0 | 17480/18000 batches | ms/batch 9036.48 | loss  0.17 | valid  0.12
# | epoch   0 | 17485/18000 batches | ms/batch 9038.96 | loss  0.14 | valid  0.12
# | epoch   0 | 17490/18000 batches | ms/batch 9041.88 | loss  0.12 | valid  0.12
# | epoch   0 | 17495/18000 batches | ms/batch 9044.37 | loss  0.11 | valid  0.12
# | epoch   0 | 17500/18000 batches | ms/batch 9046.99 | loss  0.13 | valid  0.12
# | epoch   0 | 17505/18000 batches | ms/batch 9049.70 | loss  0.13 | valid  0.12
# | epoch   0 | 17510/18000 batches | ms/batch 9052.40 | loss  0.13 | valid  0.11
# | epoch   0 | 17515/18000 batches | ms/batch 9055.20 | loss  0.12 | valid  0.11
# | epoch   0 | 17520/18000 batches | ms/batch 9057.64 | loss  0.14 | valid  0.11
# | epoch   0 | 17525/18000 batches | ms/batch 9060.02 | loss  0.15 | valid  0.11
# | epoch   0 | 17530/18000 batches | ms/batch 9062.42 | loss  0.15 | valid  0.12
# | epoch   0 | 17535/18000 batches | ms/batch 9064.72 | loss  0.13 | valid  0.12
# | epoch   0 | 17540/18000 batches | ms/batch 9067.15 | loss  0.12 | valid  0.12
# | epoch   0 | 17545/18000 batches | ms/batch 9069.50 | loss  0.12 | valid  0.12
# | epoch   0 | 17550/18000 batches | ms/batch 9072.02 | loss  0.12 | valid  0.12
# | epoch   0 | 17555/18000 batches | ms/batch 9074.40 | loss  0.13 | valid  0.12
# | epoch   0 | 17560/18000 batches | ms/batch 9076.97 | loss  0.13 | valid  0.12
# | epoch   0 | 17565/18000 batches | ms/batch 9079.52 | loss  0.14 | valid  0.12
# | epoch   0 | 17570/18000 batches | ms/batch 9081.99 | loss  0.14 | valid  0.12
# | epoch   0 | 17575/18000 batches | ms/batch 9084.51 | loss  0.10 | valid  0.12
# | epoch   0 | 17580/18000 batches | ms/batch 9086.80 | loss  0.12 | valid  0.12
# | epoch   0 | 17585/18000 batches | ms/batch 9089.37 | loss  0.13 | valid  0.12
# | epoch   0 | 17590/18000 batches | ms/batch 9091.87 | loss  0.12 | valid  0.12
# | epoch   0 | 17595/18000 batches | ms/batch 9094.38 | loss  0.13 | valid  0.12
# | epoch   0 | 17600/18000 batches | ms/batch 9096.80 | loss  0.14 | valid  0.12
# | epoch   0 | 17605/18000 batches | ms/batch 9099.13 | loss  0.13 | valid  0.12
# | epoch   0 | 17610/18000 batches | ms/batch 9101.49 | loss  0.15 | valid  0.12
# | epoch   0 | 17615/18000 batches | ms/batch 9103.99 | loss  0.15 | valid  0.12
# | epoch   0 | 17620/18000 batches | ms/batch 9106.86 | loss  0.14 | valid  0.12
# | epoch   0 | 17625/18000 batches | ms/batch 9109.45 | loss  0.13 | valid  0.12
# | epoch   0 | 17630/18000 batches | ms/batch 9112.45 | loss  0.10 | valid  0.12
# | epoch   0 | 17635/18000 batches | ms/batch 9115.07 | loss  0.14 | valid  0.12
# | epoch   0 | 17640/18000 batches | ms/batch 9117.93 | loss  0.16 | valid  0.12
# | epoch   0 | 17645/18000 batches | ms/batch 9120.92 | loss  0.14 | valid  0.12
# | epoch   0 | 17650/18000 batches | ms/batch 9123.89 | loss  0.12 | valid  0.12
# | epoch   0 | 17655/18000 batches | ms/batch 9126.47 | loss  0.16 | valid  0.12
# | epoch   0 | 17660/18000 batches | ms/batch 9128.72 | loss  0.12 | valid  0.12
# | epoch   0 | 17665/18000 batches | ms/batch 9131.10 | loss  0.14 | valid  0.12
# | epoch   0 | 17670/18000 batches | ms/batch 9133.47 | loss  0.14 | valid  0.12
# | epoch   0 | 17675/18000 batches | ms/batch 9135.89 | loss  0.12 | valid  0.12
# | epoch   0 | 17680/18000 batches | ms/batch 9138.53 | loss  0.13 | valid  0.12
# | epoch   0 | 17685/18000 batches | ms/batch 9141.21 | loss  0.15 | valid  0.12
# | epoch   0 | 17690/18000 batches | ms/batch 9145.58 | loss  0.13 | valid  0.12
# | epoch   0 | 17695/18000 batches | ms/batch 9148.11 | loss  0.09 | valid  0.12
# | epoch   0 | 17700/18000 batches | ms/batch 9150.89 | loss  0.12 | valid  0.12
# | epoch   0 | 17705/18000 batches | ms/batch 9153.48 | loss  0.13 | valid  0.13
# | epoch   0 | 17710/18000 batches | ms/batch 9155.99 | loss  0.13 | valid  0.13
# | epoch   0 | 17715/18000 batches | ms/batch 9158.45 | loss  0.14 | valid  0.13
# | epoch   0 | 17720/18000 batches | ms/batch 9161.30 | loss  0.14 | valid  0.13
# | epoch   0 | 17725/18000 batches | ms/batch 9164.02 | loss  0.12 | valid  0.13
# | epoch   0 | 17730/18000 batches | ms/batch 9166.42 | loss  0.14 | valid  0.12
# | epoch   0 | 17735/18000 batches | ms/batch 9168.88 | loss  0.14 | valid  0.12
# | epoch   0 | 17740/18000 batches | ms/batch 9171.31 | loss  0.11 | valid  0.12
# | epoch   0 | 17745/18000 batches | ms/batch 9174.28 | loss  0.10 | valid  0.12
# | epoch   0 | 17750/18000 batches | ms/batch 9177.05 | loss  0.09 | valid  0.12
# | epoch   0 | 17755/18000 batches | ms/batch 9179.81 | loss  0.15 | valid  0.12
# | epoch   0 | 17760/18000 batches | ms/batch 9182.20 | loss  0.15 | valid  0.12
# | epoch   0 | 17765/18000 batches | ms/batch 9184.76 | loss  0.14 | valid  0.12
# | epoch   0 | 17770/18000 batches | ms/batch 9187.53 | loss  0.14 | valid  0.12
# | epoch   0 | 17775/18000 batches | ms/batch 9190.09 | loss  0.11 | valid  0.12
# | epoch   0 | 17780/18000 batches | ms/batch 9192.70 | loss  0.12 | valid  0.12
# | epoch   0 | 17785/18000 batches | ms/batch 9195.44 | loss  0.13 | valid  0.12
# | epoch   0 | 17790/18000 batches | ms/batch 9198.24 | loss  0.11 | valid  0.13
# | epoch   0 | 17795/18000 batches | ms/batch 9200.81 | loss  0.11 | valid  0.12
# | epoch   0 | 17800/18000 batches | ms/batch 9203.23 | loss  0.11 | valid  0.12
# | epoch   0 | 17805/18000 batches | ms/batch 9205.76 | loss  0.11 | valid  0.12
# | epoch   0 | 17810/18000 batches | ms/batch 9208.37 | loss  0.12 | valid  0.12
# | epoch   0 | 17815/18000 batches | ms/batch 9210.87 | loss  0.13 | valid  0.12
# | epoch   0 | 17820/18000 batches | ms/batch 9213.33 | loss  0.13 | valid  0.12
# | epoch   0 | 17825/18000 batches | ms/batch 9215.74 | loss  0.12 | valid  0.12
# | epoch   0 | 17830/18000 batches | ms/batch 9218.20 | loss  0.13 | valid  0.12
# | epoch   0 | 17835/18000 batches | ms/batch 9220.88 | loss  0.13 | valid  0.12
# | epoch   0 | 17840/18000 batches | ms/batch 9223.64 | loss  0.13 | valid  0.12
# | epoch   0 | 17845/18000 batches | ms/batch 9226.57 | loss  0.13 | valid  0.12
# | epoch   0 | 17850/18000 batches | ms/batch 9229.01 | loss  0.14 | valid  0.12
# | epoch   0 | 17855/18000 batches | ms/batch 9231.21 | loss  0.14 | valid  0.12
# | epoch   0 | 17860/18000 batches | ms/batch 9233.45 | loss  0.11 | valid  0.12
# | epoch   0 | 17865/18000 batches | ms/batch 9235.71 | loss  0.14 | valid  0.12
# | epoch   0 | 17870/18000 batches | ms/batch 9238.09 | loss  0.13 | valid  0.12
# | epoch   0 | 17875/18000 batches | ms/batch 9240.71 | loss  0.09 | valid  0.12
# | epoch   0 | 17880/18000 batches | ms/batch 9243.32 | loss  0.12 | valid  0.12
# | epoch   0 | 17885/18000 batches | ms/batch 9245.83 | loss  0.12 | valid  0.12
# | epoch   0 | 17890/18000 batches | ms/batch 9248.30 | loss  0.12 | valid  0.12
# | epoch   0 | 17895/18000 batches | ms/batch 9250.86 | loss  0.11 | valid  0.12
# | epoch   0 | 17900/18000 batches | ms/batch 9253.45 | loss  0.13 | valid  0.12
# | epoch   0 | 17905/18000 batches | ms/batch 9255.82 | loss  0.16 | valid  0.12
# | epoch   0 | 17910/18000 batches | ms/batch 9258.38 | loss  0.13 | valid  0.13
# | epoch   0 | 17915/18000 batches | ms/batch 9261.02 | loss  0.12 | valid  0.12
# | epoch   0 | 17920/18000 batches | ms/batch 9263.58 | loss  0.11 | valid  0.12
# | epoch   0 | 17925/18000 batches | ms/batch 9266.20 | loss  0.11 | valid  0.12
# | epoch   0 | 17930/18000 batches | ms/batch 9268.56 | loss  0.12 | valid  0.12
# | epoch   0 | 17935/18000 batches | ms/batch 9271.14 | loss  0.13 | valid  0.12
# | epoch   0 | 17940/18000 batches | ms/batch 9274.06 | loss  0.11 | valid  0.13
# | epoch   0 | 17945/18000 batches | ms/batch 9276.58 | loss  0.13 | valid  0.12
# | epoch   0 | 17950/18000 batches | ms/batch 9279.14 | loss  0.14 | valid  0.13
# | epoch   0 | 17955/18000 batches | ms/batch 9281.72 | loss  0.13 | valid  0.12
# | epoch   0 | 17960/18000 batches | ms/batch 9284.15 | loss  0.15 | valid  0.12
# | epoch   0 | 17965/18000 batches | ms/batch 9286.68 | loss  0.16 | valid  0.12
# | epoch   0 | 17970/18000 batches | ms/batch 9289.30 | loss  0.12 | valid  0.12
# | epoch   0 | 17975/18000 batches | ms/batch 9291.83 | loss  0.14 | valid  0.12
# | epoch   0 | 17980/18000 batches | ms/batch 9294.18 | loss  0.15 | valid  0.12
# | epoch   0 | 17985/18000 batches | ms/batch 9296.62 | loss  0.15 | valid  0.12
# | epoch   0 | 17990/18000 batches | ms/batch 9299.28 | loss  0.12 | valid  0.12
# | epoch   0 | 17995/18000 batches | ms/batch 9301.89 | loss  0.14 | valid  0.12
#
#
# Epoch0 Loss:2.7397947633289732e-05
# Loss Validation:0.11493253707885742
# Time 9303.936094999313

# %%
R1 = []
R2 = []
RL = []
for j in tqdm(range(nbatch_eval)):
    src, segs, clss, mask, mask_cls, adj, labels = make_batch(eval_batches[j])
    pred = classifier(src, segs, clss, mask, mask_cls, adj)
    index = np.argsort(pred)[:, -2:]
    for e in range(len(index)):
        st = ''
        for i in index[e]:
            st += eval_batches[j][e]['src_txt'][i]
        score = rouge.get_scores([st],[eval_batches[j][e]['tgt_txt']])[0]
        R1.append(score['rouge-1']['f'])
        R2.append(score['rouge-2']['f'])
        RL.append(score['rouge-l']['f'])
        
r1_score = sum(R1)/len(R1)
r2_score = sum(R2)/len(R1)
rl_score = sum(RL)/len(R1)
print(f'R1:{r1_score}, R2:{r2_score}, RL:{rl_score}')
# Out:
# 100%|██████████| 2000/2000 [09:24<00:00,  3.54it/s]
# R1:0.3107025678394263, R2:0.11329044899686572, RL:0.24957127303881962
